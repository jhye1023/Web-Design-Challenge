# %%
import pandas as pd

# Read the csv file in
file_to_load = "Resources/cities.csv"
df = pd.read_csv(file_to_load)
df.to_html('cities.htlm', index = False)

# Assign to string
#htmTable = df.to_html()
